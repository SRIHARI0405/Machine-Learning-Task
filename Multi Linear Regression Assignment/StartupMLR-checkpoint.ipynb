# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline

# %%
#load the data set
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
#print the frist five rows
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#check the datatype
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
#check the dimensinal
df.shape
# Out:
# (50, 5)

# %%
#check the info about the datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#Rename the columns in the dataset
df.rename(columns = {'R&D Spend': 'RDSpend','Marketing Spend':'MarketingSpend'},inplace = True)

# %%
#descriptive anlyasis
df.describe()
# Out:
#              RDSpend  Administration  MarketingSpend         Profit
# count      50.000000       50.000000       50.000000      50.000000
# mean    73721.615600   121344.639600   211025.097800  112012.639200
# std     45902.256482    28017.802755   122290.310726   40306.180338
# min         0.000000    51283.140000        0.000000   14681.400000
# 25%     39936.370000   103730.875000   129300.132500   90138.902500
# 50%     73051.080000   122699.795000   212716.240000  107978.190000
# 75%    101602.800000   144842.180000   299469.085000  139765.977500
# max    165349.200000   182645.560000   471784.100000  192261.830000

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['State'] = LE.fit_transform(df['State'])

# %%
#Transformation
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
for i in range(0,49):
    df.iloc[:,0:5] = SS.fit_transform(df.iloc[:,0:5])

# %%
df
# Out:
#      RDSpend  Administration  MarketingSpend     State    Profit
# 0   2.016411        0.560753        2.153943  1.212678  2.011203
# 1   1.955860        1.082807        1.923600 -1.212678  1.999430
# 2   1.754364       -0.728257        1.626528  0.000000  1.980842
# 3   1.554784       -0.096365        1.422210  1.212678  1.776627
# 4   1.504937       -1.079919        1.281528  0.000000  1.357740
# 5   1.279800       -0.776239        1.254210  1.212678  1.127250
# 6   1.340066        0.932147       -0.688150 -1.212678  1.105481
# 7   1.245057        0.871980        0.932186  0.000000  1.096210
# 8   1.030369        0.986952        0.830887  1.212678  1.007470
# 9   1.091819       -0.456640        0.776107 -1.212678  0.946022
# 10  0.620398       -0.387599        0.149807  0.000000  0.854847
# 11  0.593085       -1.065540        0.319834 -1.212678  0.808168
# 12  0.443260        0.215449        0.320617  0.000000  0.741155
# ...

# %%
#check the null value
df.isnull().sum()
# Out:
# RDSpend           0
# Administration    0
# MarketingSpend    0
# State             0
# Profit            0
# dtype: int64

# %%
#correlation matrix
df.corr()
# Out:
#                  RDSpend  Administration  MarketingSpend     State    Profit
# RDSpend         1.000000        0.241955        0.724248  0.104685  0.972900
# Administration  0.241955        1.000000       -0.032154  0.011847  0.200717
# MarketingSpend  0.724248       -0.032154        1.000000  0.077670  0.747766
# State           0.104685        0.011847        0.077670  1.000000  0.101796
# Profit          0.972900        0.200717        0.747766  0.101796  1.000000

# %%
sbn.pairplot(df)

# %%
#check the multi-collinearity issue
import statsmodels.formula.api as smf
model = smf.ols('Profit~Administration+RDSpend+MarketingSpend+State',data = df).fit()

# %%
model.params
# Out:
# Intercept         5.551115e-17
# Administration   -1.864730e-02
# RDSpend           9.176307e-01
# MarketingSpend    8.260967e-02
# State            -4.612912e-04
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Thu, 18 May 2023   Prob (F-statistic):           8.51e-29
# Time:                        13:32:40   Log-Likelihood:                 4.3223
# No. Observations:                  50   AIC:                             1.355
# Df Residuals:                      45   BIC:                             10.92
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
#model 1 :-r2 score= 95% and multicollinearity issues exist
X=df.iloc[:,0:4] 
Y=df["Profit"]

# %%
#model 2 #r2 score=95% and multicollinearity issues doesnot exist
X=df[["RDSpend","MarketingSpend"]]
Y=df["Profit"]

# %%
#model 3 #r2 score= 94% and multicollinearity issues doesnot exist
X=df[["RDSpend"]] 
Y=df["Profit"]

# %%
#model 4 #r2 score= 92% and multicollinearity issues exist
X=df[["RDSpend","Administration"]] 
Y=df["Profit"]

# %%
#model 5 #r2 score= 89% and multicollinearity issues exist
X=df[["MarketingSpend","Administration"]]
Y=df["Profit"]

# %%
#model 6 #r2 score= 95% and multicollinearity issues exist
X=df[["RDSpend","State"]] 
Y=df["Profit"]

# %%
import statsmodels.api as sm
qq_plot = sm.qqplot(data = model.resid , line = 'q' )
plt.title('Normal Q-Q plot of residuals')
plt.show()

# %%
#Residual Plot for Homoscedasticity:
plt.scatter((model.fittedvalues),(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardized fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
#Residual Vs Regressors:
figsize = plt.figure(figsize = (16,8))
figsize = sm.graphics.plot_regress_exog(model,'RDSpend',fig = figsize)
plt.show()
# Out:
# eval_env: 1

# %%
figsize = plt.figure(figsize = (16,9))
figsize = sm.graphics.plot_regress_exog(model,'Administration',fig = figsize)
plt.show()
# Out:
# eval_env: 1

# %%
figsize = plt.figure(figsize = (16,9))
figsize = sm.graphics.plot_regress_exog(model,'MarketingSpend',fig = figsize)
plt.show()
# Out:
# eval_env: 1

# %%
#Model Deletion Dignostics:
#Detecting influencers/outliers
#Using Cook's Distance
model_influencers = model.get_influence()
(a,_) = model_influencers.cooks_distance

# %%
#Plot the influencers values using stem plot
plt.subplots(figsize = (16,4))
plt.stem(np.arange(len(df)),np.round(a,3))
plt.title('Influencers Plot')
plt.xlabel('Raw index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#Index and values of influencer
(np.argmax(a), np.max(a))
# Out:
# (49, 0.30602819546993554)

# %%
#High Influence Point
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
#Leverage_cutoff
k = df.shape[1]
n = df.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
#Deleting the 49 value because it causes high influence
df[df.index.isin([49])]
# Out:
#      RDSpend  Administration  MarketingSpend     State    Profit
# 49 -1.622362       -0.157226       -1.369985 -1.212678 -2.439313

# %%
df2 = df.drop(df.index[49],axis = 0)
df2
# Out:
#      RDSpend  Administration  MarketingSpend     State    Profit
# 0   2.016411        0.560753        2.153943  1.212678  2.011203
# 1   1.955860        1.082807        1.923600 -1.212678  1.999430
# 2   1.754364       -0.728257        1.626528  0.000000  1.980842
# 3   1.554784       -0.096365        1.422210  1.212678  1.776627
# 4   1.504937       -1.079919        1.281528  0.000000  1.357740
# 5   1.279800       -0.776239        1.254210  1.212678  1.127250
# 6   1.340066        0.932147       -0.688150 -1.212678  1.105481
# 7   1.245057        0.871980        0.932186  0.000000  1.096210
# 8   1.030369        0.986952        0.830887  1.212678  1.007470
# 9   1.091819       -0.456640        0.776107 -1.212678  0.946022
# 10  0.620398       -0.387599        0.149807  0.000000  0.854847
# 11  0.593085       -1.065540        0.319834 -1.212678  0.808168
# 12  0.443260        0.215449        0.320617  0.000000  0.741155
# ...

# %%
#After removing the 49 rows check the multi-collinearity issue
import statsmodels.formula.api as smf
model = smf.ols('Profit~Administration+RDSpend+MarketingSpend+State',data = df2).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     276.6
# Date:                Thu, 18 May 2023   Prob (F-statistic):           1.45e-30
# Time:                        13:32:44   Log-Likelihood:                 13.112
# No. Observations:                  49   AIC:                            -16.22
# Df Residuals:                      44   BIC:                            -6.765
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
#model 1 :-r2 score= 92% and multicollinearity issues exist
X=df2.iloc[:,0:4] 
Y=df2["Profit"]

# %%
#model 2 #r2 score=94% and multicollinearity issues doesnot exist
X=df2[["RDSpend","MarketingSpend"]]
Y=df2["Profit"]

# %%
#model 3 #r2 score= 95% and multicollinearity issues doesnot exist
X=df2[["RDSpend"]] 
Y=df2["Profit"]

# %%
#model 4 #r2 score= 95% and multicollinearity issues exist
X=df2[["RDSpend","Administration"]] 
Y=df2["Profit"]

# %%
#model 5 #r2 score= 98% and multicollinearity issues exist
X=df2[["MarketingSpend","Administration"]]
Y=df2["Profit"]

# %%
#model 6 #r2 score= 95% and multicollinearity issues exist
X=df2[["RDSpend","State"]] 
Y=df2["Profit"]

# %%
#Data Partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 42)

# %%
X_train.shape
# Out:
# (34, 2)

# %%
Y_train.shape
# Out:
# (34,)

# %%
#model fitting
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_train = LR.predict(X_train)
Y_pred_test = LR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('Training Error',np.sqrt(mean_squared_error(Y_pred_train,Y_train)).round(2))
print('Testing Error',np.sqrt(mean_squared_error(Y_pred_test,Y_test)).round(2))
# Out:
# Training Error 0.2
# Testing Error 0.2

# %%
##After Deleting 49th row i got better accuracy comparded to previous one.
