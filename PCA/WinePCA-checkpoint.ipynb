# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
df = pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
#Data transformation
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X = df.iloc[:,1:]
X_scale = SS.fit_transform(X)

# %%
#PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=(3))
pc = pca.fit_transform(X_scale)
pc_value = pd.DataFrame(pc,columns=['PC1','PC2','PC3'])

# %%
#hierarchial clustering
import matplotlib.pyplot as plt
plt.scatter(pc_value['PC1'],pc_value['PC2'])

# %%
import scipy.cluster.hierarchy as shc
single_dend = shc.dendrogram(shc.linkage(pc_value,method='single'))
complete_dend = shc.dendrogram(shc.linkage(pc_value,method='complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='single')
cluster = AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='complete')
Y = cluster.fit_predict(pc_value)
Y = pd.DataFrame(Y)
Y.value_counts()
# Out:
# 0    106
# 1     50
# 2     22
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(pc_value['PC1'],pc_value['PC2'],c=cluster.labels_, cmap='rainbow')

# %%
#kmeans
from sklearn.cluster import KMeans
KM = KMeans(n_clusters=3)
Y=KM.fit_predict(pc_value)
Y = pd.DataFrame(Y)
Y.value_counts()
# Out:
# 1    65
# 0    62
# 2    51
# dtype: int64

# %%
k_value=[]
for i in range(2,10):
    KM = KMeans(n_clusters=i)
    Y=KM.fit_predict(pc_value)
    k_value.append(KM.inertia_)
print(k_value)
#elbow cure
import matplotlib.pyplot as plt
plt.scatter(range(2,10),k_value)
plt.plot(range(2,10),k_value)
# Out:
# [886.161136482348, 513.0564645910756, 429.6280819087466, 370.4095663154305, 325.03113463960153, 286.8767555883232, 261.0561899947648, 236.5276169506314]

# %%
#kmeans
from sklearn.cluster import KMeans
KM = KMeans(n_clusters=4)
Y=KM.fit_predict(pc_value)
Y = pd.DataFrame(Y)
Y.value_counts()
# Out:
# 2    57
# 0    51
# 3    38
# 1    32
# dtype: int64

# %%
#DBSCAN
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=2 , min_samples=3) #eps = epsalon = radius
dbscan.fit(X_scale)
y=dbscan.labels_
Y=pd.DataFrame(y)
Y.value_counts()
# Out:
#  0    78
# -1    64
#  2    20
#  1     6
#  3     5
#  4     5
# dtype: int64

# %%
#from the above all clustering methods KMeans is giving results accurately with 4 clusters
