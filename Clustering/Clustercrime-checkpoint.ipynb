# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
df = pd.read_csv('crime_data.csv')
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
#check the dimensional
df.shape
# Out:
# (50, 5)

# %%
#check the datatype
df.dtypes
# Out:
# Unnamed: 0     object
# Murder        float64
# Assault         int64
# UrbanPop        int64
# Rape          float64
# dtype: object

# %%
#print the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
#check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
#check the null value
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Murder        0
# Assault       0
# UrbanPop      0
# Rape          0
# dtype: int64

# %%
X = df.iloc[:,1:]

# %%
#Data Transformation
from sklearn.preprocessing import StandardScaler
for i in X:
    SS = StandardScaler()
    X = SS.fit_transform(X)

# %%
X = pd.DataFrame(X)
X
# Out:
#            0         1         2         3
# 0   1.255179  0.790787 -0.526195 -0.003451
# 1   0.513019  1.118060 -1.224067  2.509424
# 2   0.072361  1.493817  1.009122  1.053466
# 3   0.234708  0.233212 -1.084492 -0.186794
# 4   0.281093  1.275635  1.776781  2.088814
# 5   0.025976  0.402909  0.869548  1.883901
# 6  -1.040880 -0.736484  0.799761 -1.092723
# 7  -0.437875  0.815030  0.450825 -0.585834
# 8   1.765415  1.990786  1.009122  1.150530
# 9   2.229265  0.487757 -0.386621  0.492653
# 10 -0.577030 -1.512241  1.218484 -0.111300
# 11 -1.203228 -0.615272 -0.805344 -0.758392
# 12  0.605789  0.948363  1.218484  0.298525
# 13 -0.136372 -0.700121 -0.037685 -0.025021
# 14 -1.295998 -1.391029 -0.595982 -1.071153
# 15 -0.414682 -0.675878  0.032102 -0.348567
# 16  0.443441 -0.748605 -0.944918 -0.531910
# 17  1.765415  0.948363  0.032102  0.104398
# 18 -1.319191 -1.063757 -1.014705 -1.448624
# 19  0.814521  1.566544  0.101889  0.708350
# 20 -0.785763 -0.263757  1.358058 -0.531910
# ...

# %%
#dendrogram construction
import scipy.cluster.hierarchy as shc
dendo_single = shc.dendrogram(shc.linkage(X,method = 'single'))
dendo_complete = shc.dendrogram(shc.linkage(X,method = 'complete'))

# %%
#Apply Hirarical Clustering
from sklearn.cluster import AgglomerativeClustering
K = AgglomerativeClustering(n_clusters=2,affinity="euclidean",linkage="single")
X = K.fit_predict(X1)

# %%
Y_new = pd.DataFrame(X)
Y_new.value_counts()
# Out:
# 0    49
# 1     1
# dtype: int64

# %%
X1 = df.iloc[:,1:]

# %%
#using K-means cluster
from sklearn.cluster import KMeans
cluster_value = []
for i in range(2,20):
    km = KMeans(n_clusters=i)
    km.fit_predict(X1)
    cluster_value.append(km.inertia_)
print(cluster_value)
len(cluster_value)
# Out:
# [96399.02814449919, 47964.26535714285, 34728.629357142854, 24417.023523809527, 18768.000666666667, 15779.449714285713, 13329.361976190476, 11748.17938888889, 10272.546452380951, 9246.415785714284, 8065.5605, 7039.429833333334, 6535.109166666667, 5692.482500000001, 5333.264833333334, 4737.319, 4121.4145, 3670.6215]
# 18

# %%
import matplotlib.pyplot as plt
plt.plot(range(2,20),cluster_value)
plt.scatter(range(2,20),cluster_value)
plt.show()

# %%
from sklearn.cluster import KMeans
K = KMeans(n_clusters = 6)
k = K.fit_predict(X1)
y_new = pd.DataFrame(k)
y_new.value_counts()
# Out:
# 1    12
# 0    10
# 4    10
# 2     8
# 5     6
# 3     4
# dtype: int64

# %%
#DBSCAN
from sklearn.cluster import DBSCAN
D = DBSCAN(eps=4, min_samples=2) 
D.fit(X1)
y=D.labels_
Y=pd.DataFrame(y)
Y.value_counts()
# Out:
# -1    44
#  0     2
#  1     2
#  2     2
# dtype: int64

# %%
#After applying the cluster algorithm i got kmeans has 6 clusters.
