# %%
import pandas as pd
df = pd.read_excel('CocaCola_Sales_Rawdata.xlsx')

# %%
df.isnull().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df['Sales'])

# %%
df.hist('Sales')
# Out:
# array([[<AxesSubplot:title={'center':'Sales'}>]], dtype=object)

# %%
df['Sales'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns
fig = plt.subplots(figsize=(12,2))
ax = sns.boxplot(df['Sales'], whis=1.5)
# Out:
# C:\Users\srihari\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from pylab import rcParams
import statsmodels.api as sma
rcParams['figure.figsize'] = 12,8
decomposition = sma.tsa.seasonal_decompose(df.Sales, model='additive',freq = 10)
fig = decomposition.plot()
plt.show()
# Out:
# <ipython-input-8-1364cc70439b>:4: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition = sma.tsa.seasonal_decompose(df.Sales, model='additive',freq = 10)

# %%
decomposition = sma.tsa.seasonal_decompose(df.Sales, model='multiplicative',freq = 10)
fig = decomposition.plot()
plt.show()
# Out:
# <ipython-input-9-cf2d00a0450d>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition = sma.tsa.seasonal_decompose(df.Sales, model='multiplicative',freq = 10)

# %%
train_len = 34
train = df[0:train_len]
test = df[34:]

# %%
train.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
test.head()
# Out:
#    Quarter   Sales
# 34   Q3_94  4461.0
# 35   Q4_94  4017.0
# 36   Q1_95  3854.0
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0

# %%
y_hat_naive = test.copy()
y_hat_naive.head()
# Out:
#    Quarter   Sales
# 34   Q3_94  4461.0
# 35   Q4_94  4017.0
# 36   Q1_95  3854.0
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0

# %%
y_hat_naive['naive_forecast'] = train['Sales'][train_len-1]

# %%
y_hat_naive.head()
# Out:
#    Quarter   Sales  naive_forecast
# 34   Q3_94  4461.0          4342.0
# 35   Q4_94  4017.0          4342.0
# 36   Q1_95  3854.0          4342.0
# 37   Q2_95  4936.0          4342.0
# 38   Q3_95  4895.0          4342.0

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='test')
plt.plot(y_hat_naive['naive_forecast'], label='Naive Forecast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Simple Average Method

# %%
y_hat_avg = test.copy()

# %%
y_hat_avg['avg_forecast'] = train['Sales'].mean()

# %%
y_hat_avg.head()
# Out:
#    Quarter   Sales  avg_forecast
# 34   Q3_94  4461.0   2641.759968
# 35   Q4_94  4017.0   2641.759968
# 36   Q1_95  3854.0   2641.759968
# 37   Q2_95  4936.0   2641.759968
# 38   Q3_95  4895.0   2641.759968

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='test')
plt.plot(y_hat_avg['avg_forecast'], label='Simple average forecast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# calculation of rmse

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
rmse = np.sqrt(mean_squared_error(test['Sales'], y_hat_naive['naive_forecast'])).round(2)
rmse
# Out:
# 483.28

# %%
mape = round(np.mean(np.abs((test['Sales'] - y_hat_naive['naive_forecast'])/test['Sales'])*100),2)
mape
# Out:
# 8.48

# %%
results = pd.DataFrame({'Method':['Naive method'], 'RMSE':[rmse], 'MAPE':[mape]})
results
# Out:
#          Method    RMSE  MAPE
# 0  Naive method  483.28  8.48

# %%
rmse = np.sqrt(mean_squared_error(test['Sales'], y_hat_avg['avg_forecast'])).round(2)
rmse
# Out:
# 1907.2

# %%
mape = round(np.mean(np.abs((test['Sales'] - y_hat_avg['avg_forecast'])/test['Sales'])*100),2)
mape
# Out:
# 40.59

# %%
results = results.append({'Method':'Simple average method', 'RMSE':rmse, 'MAPE':mape}, ignore_index=True)
results
# Out:
#                   Method     RMSE   MAPE
# 0           Naive method   483.28   8.48
# 1  Simple average method  1907.20  40.59

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
# Instantiate the model
model = SimpleExpSmoothing(train['Sales'])
# Fit the model with alpha = 0.2 

model_fit = model.fit(smoothing_level = 0.2, optimized=False)
model_fit.params
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# {'smoothing_level': 0.2,
#  'smoothing_trend': None,
#  'smoothing_seasonal': None,
#  'damping_trend': nan,
#  'initial_level': 1734.8269996643066,
#  'initial_trend': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
y_hat_ses = test.copy()
y_hat_ses['ses_forecast'] = model_fit.forecast(8)

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='test')
plt.plot(y_hat_ses['ses_forecast'], label='Simple exponential smoothing forcast')
plt.legend(loc='best')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Sales'], y_hat_ses['ses_forecast'])).round(2)
rmse
# Out:
# 1067.41

# %%
mape = round(np.mean(np.abs((test['Sales'] - y_hat_ses['ses_forecast'])/test['Sales'])*100),2)
mape
# Out:
# 20.63

# %%
results = results.append({'Method':'Simple expenential smoothing method', 'RMSE':rmse, 'MAPE':mape}, ignore_index=True)
results
# Out:
#                                 Method     RMSE   MAPE
# 0                         Naive method   483.28   8.48
# 1                Simple average method  1907.20  40.59
# 2  Simple expenential smoothing method  1067.41  20.63

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
model_ES= ExponentialSmoothing(train["Sales"],seasonal="add",trend="add",seasonal_periods=12) #add the trend to the model
model_ES_fit = model_ES.fit(smoothing_level=0.1, smoothing_slope=0.2)
model_ES_fit.params
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# <ipython-input-60-de577da3ab28>:3: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   model_ES_fit = model_ES.fit(smoothing_level=0.1, smoothing_slope=0.2)
# {'smoothing_level': 0.1,
#  'smoothing_trend': 0.2,
#  'smoothing_seasonal': 0.38541464274590087,
#  'damping_trend': nan,
#  'initial_level': 1933.849798141555,
#  'initial_trend': 13.510198083509275,
#  'initial_seasons': array([-351.0702467 ,  145.90935274,  242.3646075 ,  -30.31404724,
#         -437.71910809,  112.40704396,  -33.17846159, -215.10874528,
#         -365.70726223,  121.68782895,  -68.61695264, -328.96364659]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
y_hat_es = test.copy()
y_hat_es['es_forecast'] = model_ES_fit.forecast(8)

# %%
rmse = np.sqrt(mean_squared_error(test['Sales'], y_hat_es['es_forecast'])).round(2)
rmse
# Out:
# 294.61

# %%
mape = round(np.mean(np.abs((test['Sales'] - y_hat_es['es_forecast'])/test['Sales'])*100),2)
mape
# Out:
# 4.94

# %%
results = results.append({'Method':'expenential smoothing with additive seasonality ,additive trend', 'RMSE':rmse, 'MAPE':mape}, ignore_index=True)
results
# Out:
#                                               Method     RMSE   MAPE
# 0                                       Naive method   483.28   8.48
# 1                              Simple average method  1907.20  40.59
# 2                Simple expenential smoothing method  1067.41  20.63
# 3  expenential smoothing with additive seasonalit...   294.61   4.94

# %%
model_ES_mu_ad= ExponentialSmoothing(train["Sales"],seasonal="mul",trend="add",seasonal_periods=12) #add the trend to the model
model_ES_mu_ad_fit = model_ES_mu_ad.fit(smoothing_level=0.1, smoothing_slope=0.2)
model_ES_mu_ad_fit.params
# Out:
# <ipython-input-70-63bbdcf6cd63>:2: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   model_ES_mu_ad_fit = model_ES_mu_ad.fit(smoothing_level=0.1, smoothing_slope=0.2)
# {'smoothing_level': 0.1,
#  'smoothing_trend': 0.2,
#  'smoothing_seasonal': 0.5638370965348893,
#  'damping_trend': nan,
#  'initial_level': 2138.66635358151,
#  'initial_trend': 40.052957152935,
#  'initial_seasons': array([0.89058503, 1.08056641, 1.18448329, 1.00721177, 0.79276221,
#         1.01635224, 0.95359612, 0.93102235, 0.87397153, 1.08158798,
#         0.99505489, 0.94744217]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
y_hat_es_mu_ad = test.copy()
y_hat_es_mu_ad['es_mu_ad_forecast'] = model_ES_mu_ad_fit.forecast(8)

# %%
rmse = np.sqrt(mean_squared_error(test['Sales'], y_hat_es_mu_ad['es_mu_ad_forecast'])).round(2)
rmse
# Out:
# 234.72

# %%
mape = round(np.mean(np.abs((test['Sales'] - y_hat_es_mu_ad['es_mu_ad_forecast'])/test['Sales'])*100),2)
mape
# Out:
# 4.86

# %%
results = results.append({'Method':'expenential smoothing with multilicative seasonality ,additive trend', 'RMSE':rmse, 'MAPE':mape}, ignore_index=True)
results
# Out:
#                                               Method     RMSE   MAPE
# 0                                       Naive method   483.28   8.48
# 1                              Simple average method  1907.20  40.59
# 2                Simple expenential smoothing method  1067.41  20.63
# 3  expenential smoothing with additive seasonalit...   294.61   4.94
# 4  expenential smoothing with multilicative seaso...   234.72   4.86
